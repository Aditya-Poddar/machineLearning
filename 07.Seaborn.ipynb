# %% [markdown]
# # Seaborn

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
# %matplotlib inline

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### correlation Heatmap is feature of seaborn which is used to find the correlation between each of data sets.

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Contninuous Plot
# - It is used to do data analysis of continuous data.
# - Joint plot
# - Dist plot
# - Pair plot
#
# -----------------------------------------------------------------------
# ### Joint Plot
# - Univarite Plot
# - Joint plot are performed by univariate analysis.
# - It is used to find the relationsip between two numerical values.

# %%
sns.jointplot(x='tip',y='total_bill',data=df, kind='hex') #hex - hexagonal

# %%
sns.jointplot(x='tip',y='total_bill',data=df, kind='scatter')

# %%
sns.jointplot(x='tip',y='total_bill',data=df, kind='reg') # reg - regression

# %%
sns.jointplot(x='tip',y='total_bill',data=df, kind='hist') # hist - histogram

# %% [markdown]
# ### Pair Plot
# - defien relationship between more than two numerical values.

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='day')

# %%
df['smoker'].value_counts()    # to count the values.
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
plt.pie(df['sex'].value_counts(),labels=df["sex"].value_counts())
plt.show()

# %% [markdown]
# ### Dist plot
# - It is used to check the distribution of the features.

# %%
sns.distplot(df['total_bill'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(df['tip'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df['total_bill'],kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# ## Categorical Plot
#
# - Helps to do data analysis of categorial data.
#
# - boxplot
# - barplot
# - violinplot
# - countplot

# %% [markdown]
# #### Count Plot

# %%
sns.countplot('sex',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(df['sex'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot('smoker',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot('day',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# ### Bar Plot

# %%
sns.barplot(y=df['tip'],x=df['smoker'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(y=df['total_bill'],x=df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x=df['tip'],y=df['total_bill'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.boxplot(x=df['sex'],y=df['tip'],color='r')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x=df['day'],y=df['tip'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x=df['total_bill'],y=df['day'],hue=df['sex'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(x=df['total_bill'],y=df['day'],hue=df['smoker'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(y=df['total_bill'],x=df['sex'],hue=df['day'])
plt.savefig('Image/boxPlotOfTotallBill_sex_dayWise')  # to save the image.

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# - violin Plot helps to see both the distrivution of data density and box plot

# %%
sns.violinplot(x=df['day'],y=df['total_bill'])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x=df['day'],y=df['total_bill'],hue=df['sex'])
plt.savefig('Image/violinPlot.png')

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.corr()  # correlation of iris data set.
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr())
# Out:
# <AxesSubplot:>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Joint plot for Iris Data set

# %%
sns.jointplot(x=iris['sepal_length'],y=iris['petal_length'],kind='reg')
#sns.jointplot(x='sepal_length',y='petal_length'data=iris,kind='reg')

# %%
sns.jointplot(x=iris['sepal_length'],y=iris['petal_length'],kind='hex')

# %% [markdown]
# ### Dist Plot

# %%
sns.distplot(iris['sepal_length'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# ### Pair plot

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# ## categorical Plot of iris data set

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x=iris['petal_length'])
plt.tight_layout()
sns.set(rc={'figure.figsize':(17.7,6.27)})

# %%
sns.countplot(x=iris['species'])
plt.title("Count Plot of Species of Iris Data set")
# Out:
# Text(0.5, 1.0, 'Count Plot of Species of Iris Data set')

# %% [markdown]
# ### Barplot

# %%
sns.barplot(x=iris['sepal_length'],y=iris['petal_length'])
sns.set(rc={'figure.figsize':(15.7,6.27)})

# %% [markdown]
# ### BoxPlot

# %%
sns.boxplot(x=iris['sepal_length'],y=iris['petal_length'])
sns.set(rc={'figure.figsize':(17.7,6.27)})

# %%
sns.boxplot(x=iris['sepal_length'],y=iris['petal_length'],hue=iris['species'],width=0.8)
sns.set(rc={'figure.figsize':(16.7,6.27)})

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x=iris['sepal_length'],y=iris['petal_length'])
sns.set(rc={'figure.figsize':(17.7,6.27)})
